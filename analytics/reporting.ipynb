# %%
import json
import subprocess

import pandas as pd

from analytics.datasets.github_projects import SprintBoard
from analytics.metrics.burndown import SprintBurndown

# %% [markdown]
# ### Get GitHub Project Data
#
# Pulls GitHub project data from the following projects:
# - [Grants Equity Product Roadmap](https://github.com/orgs/HHS/projects/12)
# - [Grants Equity Sprint Planning](https://github.com/orgs/HHS/projects/13)
# - [NOFO Project Tracker](https://github.com/orgs/HHS/projects/14)

# %%
sprint_data = SprintBoard()
burndown = SprintBurndown(sprint_data, "Sprint 4")
burndown.visualize()
# Out:
# <div>                            <div id="da9fad28-59ad-4fa8-a3dc-7d6a2c624cec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da9fad28-59ad-4fa8-a3dc-7d6a2c624cec")) {                    Plotly.newPlot(                        "da9fad28-59ad-4fa8-a3dc-7d6a2c624cec",                        [{"hovertemplate":"dates=%{x}\u003cbr\u003etotal_open=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2023-08-09T00:00:00+00:00","2023-08-10T00:00:00+00:00","2023-08-11T00:00:00+00:00","2023-08-12T00:00:00+00:00","2023-08-13T00:00:00+00:00","2023-08-14T00:00:00+00:00","2023-08-15T00:00:00+00:00","2023-08-16T00:00
# ...
